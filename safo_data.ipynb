# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\fresh\\Desktop\\MY_COURSES\\3_TRESTLE_ACADEMY\\Data_Engineering_Track\\trestle_academy_dataset.csv', index = False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df = pd.read_csv('C:\\Users\\fresh\\Desktop\\MY_COURSES\\3_TRESTLE_ACADEMY\\Data_Engineering_Track\\trestle_academy_dataset.csv', index = False)
#
# TypeError: read_csv() got an unexpected keyword argument 'index'

# %%
df
# Out:
#                     name  age  gender            course enrollment_date  \
# student_id
# S0001          Student_1   30  Female      Data Science      2023-03-22
# S0002          Student_2   33  Female      Data Science      2023-01-29
# S0003          Student_3   39  Female  Data Engineering      2023-12-24
# S0004          Student_4   18    Male  Data Engineering      2023-01-09
# S0005          Student_5   21  Female   Cloud Computing      2023-05-26
# ...                  ...  ...     ...               ...             ...
# S0996        Student_996   25  Female  Data Engineering      2023-05-25
# S0997        Student_997   40    Male   AI Fundamentals      2023-08-15
# S0998        Student_998   20  Female   Cloud Computing      2023-04-22
# S0999        Student_999   40  Female   Cloud Computing      2023-07-04
# S1000       Student_1000   34    Male   AI Fundamentals      2023-09-09
#
#             final_grade is_intern
# student_id
# S0001                97        No
# ...
